# %% [markdown]
# # 📊 EDA Dataset OCR — Informasi Gizi Kemasan Makanan
# > **Tujuan:** Menganalisis kualitas dataset gambar crop dan file CSV label untuk pelatihan model CRNN deteksi teks informasi gizi.
#
# **Path Dataset:**
# - 📁 Gambar crop : `D:/ocr_crop_V3/test/`
# - 📄 Label Excel : `D:/ocr_crop_V3/valid/`
#
# **Cakupan Analisis:**
# 1. Kualitas CSV (missing, duplikat, distribusi teks)
# 2. Kualitas Gambar (resolusi, rasio aspek, brightness, blur)
# 3. Konsistensi CSV ↔ Gambar
# 4. Class balance per kategori nutrisi
# 5. Ringkasan rekomendasi untuk AI Engineer

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install dependencies
# !pip install opencv-python pandas matplotlib seaborn openpyxl tqdm -q
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 0. Setup & Konfigurasi

# %%
# Install jika belum ada
# !pip install opencv-python pandas matplotlib seaborn openpyxl tqdm -q

import os, re, warnings
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from tqdm.notebook import tqdm
from pathlib import Path

warnings.filterwarnings('ignore')
sns.set_theme(style='whitegrid', palette='viridis')
plt.rcParams.update({'figure.dpi': 150, 'font.family': 'DejaVu Sans'})

# ── KONFIGURASI PATH (Diperbaiki: menggunakan huruf kecil) ────────
IMG_DIR    = '/content/drive/MyDrive/ocr_crop_v3/test'
VALID_DIR  = '/content/drive/MyDrive/ocr_crop_v3/valid'
OUTPUT_DIR = '/content/drive/MyDrive/ocr_crop_v3/eda_output'
os.makedirs(OUTPUT_DIR, exist_ok=True)

IMG_EXTS   = {'.png', '.jpg', '.jpeg', '.bmp', '.webp'}
NUTRISI_CLASSES = ['calories', 'fat', 'carbs', 'sugar', 'sodium']  # sesuaikan jika berbeda

print('✅ Setup selesai')
print(f'   IMG_DIR   : {IMG_DIR}')
print(f'   VALID_DIR : {VALID_DIR}')
print(f'   OUTPUT_DIR: {OUTPUT_DIR}')
# Out:
# ✅ Setup selesai
#    IMG_DIR   : /content/drive/MyDrive/ocr_crop_v3/test
#    VALID_DIR : /content/drive/MyDrive/ocr_crop_v3/valid
#    OUTPUT_DIR: /content/drive/MyDrive/ocr_crop_v3/eda_output

# %% [markdown]
# ## 1. Load Data

# %%
# ── Load Excel → DataFrame CSV ────────────────────────────────
# Debug: List contents of VALID_DIR
print(f'Mengecek isi VALID_DIR: {VALID_DIR}')
try:
    valid_dir_contents = list(Path(VALID_DIR).iterdir())
    if not valid_dir_contents:
        print('❌ VALID_DIR kosong atau tidak dapat diakses.')
    else:
        print(f'   Ditemukan: {[f.name for f in valid_dir_contents]}')

    excel_files = list(Path(VALID_DIR).glob('*.xlsx')) + list(Path(VALID_DIR).glob('*.xls'))
    csv_files   = list(Path(VALID_DIR).glob('*.csv'))

    if excel_files:
        df_label = pd.read_excel(excel_files[0])
        print(f'📄 Excel dimuat: {excel_files[0].name} ({len(df_label)} baris)')
    elif csv_files:
        df_label = pd.read_csv(csv_files[0])
        print(f'📄 CSV dimuat: {csv_files[0].name} ({len(df_label)} baris)')
    else:
        raise FileNotFoundError('❌ Tidak ada file Excel/CSV di VALID_DIR')

    # Normalisasi nama kolom
    df_label.columns = df_label.columns.str.strip().str.lower()
    print(f'   Kolom: {list(df_label.columns)}')
    display(df_label.head())
except Exception as e:
    print(f'An error occurred: {e}')
# Out:
# Mengecek isi VALID_DIR: /content/drive/MyDrive/ocr_crop_v3/valid
#    Ditemukan: ['valid.xlsx']
# 📄 Excel dimuat: valid.xlsx (2490 baris)
#    Kolom: ['file_name', 'text']
#            file_name                           text
# 0  calories_0002.png  Energi Total 151 kkal 69 kcal
# 1  calories_0010.png           Energi Total 70 kkal
# 2  calories_0040.png          Energi Total 100 kkal
# 3  calories_0041.png           Energi Total 90 kkal
# 4  calories_0043.png           Energi Total 80 kkal

# %%
# Cek struktur folder di dalam OCR_CROP_V3
# !ls -R /content/drive/MyDrive/ocr_crop_v3/
# Out:
# /content/drive/MyDrive/ocr_crop_v3/:
# eda_ocr_nutrisi.ipynb  test  valid
#
# /content/drive/MyDrive/ocr_crop_v3/test:
# calories_0002.png  carbs_0205.png  fat_0343.png     sodium_0467.png
# calories_0010.png  carbs_0206.png  fat_0344.png     sodium_0468.png
# calories_0040.png  carbs_0207.png  fat_0345.png     sodium_0469.png
# calories_0041.png  carbs_0208.png  fat_0346.png     sodium_0470.png
# calories_0043.png  carbs_0209.png  fat_0347.png     sodium_0471.png
# calories_0044.png  carbs_0210.png  fat_0348.png     sodium_0472.png
# calories_0058.png  carbs_0211.png  fat_0349.png     sodium_0473.png
# calories_0078.png  carbs_0212.png  fat_0350.png     sodium_0474.png
# calories_0079.png  carbs_0213.png  fat_0351.png     sodium_0475.png
# calories_0080.png  carbs_0214.png  fat_0352.png     sodium_0476.png
# calories_0081.png  carbs_0215.png  fat_0353.png     sodium_0477.png
# calories_0082.png  carbs_0216.png  fat_0354.png     sodium_0478.png
# calories_0083.png  carbs_0217.png  fat_0355.png     sodium_0479.png
# calories_0084.png  carbs_0218.png  fat_0356.png     sodium_0480.png
# calories_0085.png  carbs_0219.png  fat_0357.png     sodium_0481.png
# calories_0086.png  carbs_0220.png  fat_0358.png     sodium_0482.png
# calories_0087.png  carbs_0221.png  fat_0359.png     sodium_0483.png
# calories_0088.png  carbs_0222.png  fat_0360.png     sodium_0484.png
# calories_0089.png  carbs_0223.png  fat_0361.png     sodium_0485.png
# calories_0090.png  carbs_0224.png  fat_0362.png     sodium_0486.png
# calories_0091.png  carbs_0225.png  fat_0363.png     sodium_0487.png
# calories_0092.png  carbs_0226.png  fat_0364.png     sodium_0488.png
# calories_0093.png  carbs_0227.png  fat_0365.png     sodium_0489.png
# calories_0094.png  carbs_0228.png  fat_0366.png     sodium_0490.png
# calories_0095.png  carbs_0229.png  fat_0367.png     sodium_0491.png
# calories_0096.png  carbs_0230.png  fat_0368.png     sodium_0492.png
# calories_0097.png  carbs_0231.png  fat_0369.png     sodium_0493.png
# calories_0098.png  carbs_0232.png  fat_0370.png     sodium_0494.png
# calories_0099.png  carbs_0233.png  fat_0371.png     sodium_0495.png
# calories_0100.png  carbs_0234.png  fat_0372.png     sodium_0496.png
# calories_0101.png  carbs_0235.png  fat_0373.png     sodium_0497.png
# calories_0102.png  carbs_0236.png  fat_0374.png     sodium_0498.png
# calories_0103.png  carbs_0237.png  fat_0375.png     sodium_0499.png
# calories_0104.png  carbs_0238.png  fat_0376.png     sodium_0500.png
# calories_0105.png  carbs_0239.png  fat_0377.png     sodium_0501.png
# calories_0106.png  carbs_0240.png  fat_0378.png     sodium_0502.png
# calories_0107.png  carbs_0241.png  fat_0379.png     sodium_0503.png
# calories_0108.png  carbs_0242.png  fat_0380.png     sodium_0504.png
# calories_0109.png  carbs_0243.png  fat_0381.png     sodium_0505.png
# calories_0110.png  carbs_0244.png  fat_0382.png     sodium_0506.png
# calories_0111.png  carbs_0245.png  fat_0383.png     sodium_0508.png
# calories_0112.png  carbs_0246.png  fat_0384.png     sodium_0509.png
# calories_0113.png  carbs_0247.png  fat_0385.png     sodium_0510.png
# calories_0114.png  carbs_0248.png  fat_0386.png     sodium_0511.png
# calories_0115.png  carbs_0249.png  fat_0387.png     sodium_0512.png
# calories_0116.png  carbs_0250.png  fat_0388.png     sodium_0513.png
# calories_0117.png  carbs_0251.png  fat_0389.png     sodium_0514.png
# calories_0118.png  carbs_0252.png  fat_0390.png     sodium_0515.png
# calories_0119.png  carbs_0253.png  fat_0391.png     sodium_0516.png
# calories_0120.png  carbs_0254.png  fat_0392.png     sodium_0517.png
# calories_0121.png  carbs_0256.png  fat_0393.png     sodium_0518.png
# calories_0125.png  carbs_0257.png  fat_0394.png     sodium_0519.png
# calories_0126.png  carbs_0258.png  fat_0395.png     sodium_0520.png
# calories_0127.png  carbs_0259.png  fat_0396.png     sodium_0521.png
# calories_0128.png  carbs_0260.png  fat_0397.png     sodium_0522.png
# calories_0130.png  carbs_0262.png  fat_0398.png     sodium_0523.png
# calories_0131.png  carbs_0263.png  fat_0399.png     sodium_0524.png
# calories_0132.png  carbs_0270.png  fat_0400.png     sodium_0525.png
# calories_0134.png  carbs_0271.png  fat_0401.png     sodium_0526.png
# calories_0135.png  carbs_0272.png  fat_0402.png     sodium_0527.png
# calories_0136.png  carbs_0273.png  fat_0403.png     sodium_0528.png
# calories_0137.png  carbs_0274.png  fat_0404.png     sodium_0529.png
# calories_0138.png  carbs_0275.png  fat_0405.png     sodium_0530.png
# calories_0141.png  carbs_0276.png  fat_0406.png     sodium_0531.png
# calories_0142.png  carbs_0277.png  fat_0407.png     sodium_0532.png
# calories_0143.png  carbs_0278.png  fat_0408.png     sodium_0533.png
# calories_0145.png  carbs_0279.png  fat_0409.png     sodium_0534.png
# calories_0146.png  carbs_0280.png  fat_0410.png     sodium_0535.png
# calories_0147.png  carbs_0281.png  fat_0411.png     sodium_0536.png
# calories_0148.png  carbs_0282.png  fat_0412.png     sodium_0537.png
# calories_0149.png  carbs_0283.png  fat_0413.png     sodium_0538.png
# calories_0150.png  carbs_0284.png  fat_0414.png     sodium_0539.png
# calories_0151.png  carbs_0285.png  fat_0415.png     sodium_0540.png
# calories_0152.png  carbs_0286.png  fat_0416.png     sodium_0541.png
# calories_0153.png  carbs_0287.png  fat_0417.png     sodium_0542.png
# calories_0154.png  carbs_0288.png  fat_0418.png     sodium_0543.png
# calories_0155.png  carbs_0289.png  fat_0419.png     sodium_0544.png
# calories_0156.png  carbs_0290.png  fat_0420.png     sodium_0545.png
# calories_0157.png  carbs_0291.png  fat_0421.png     sodium_0546.png
# calories_0158.png  carbs_0292.png  fat_0422.png     sodium_0547.png
# calories_0159.png  carbs_0293.png  fat_0423.png     sodium_0548.png
# calories_0160.png  carbs_0294.png  fat_0424.png     sodium_0549.png
# calories_0161.png  carbs_0295.png  fat_0425.png     sodium_0550.png
# calories_0162.png  carbs_0296.png  fat_0426.png     sodium_0551.png
# calories_0163.png  carbs_0298.png  fat_0427.png     sodium_0552.png
# calories_0164.png  carbs_0299.png  fat_0428.png     sodium_0553.png
# calories_0165.png  carbs_0300.png  fat_0429.png     sodium_0554.png
# calories_0166.png  carbs_0301.png  fat_0430.png     sodium_0555.png
# calories_0167.png  carbs_0302.png  fat_0431.png     sodium_0556.png
# calories_0168.png  carbs_0303.png  fat_0432.png     sodium_0557.png
# calories_0169.png  carbs_0304.png  fat_0433.png     sodium_0558.png
# calories_0170.png  carbs_0305.png  fat_0434.png     sodium_0559.png
# calories_0171.png  carbs_0306.png  fat_0435.png     sodium_0560.png
# calories_0172.png  carbs_0307.png  fat_0436.png     sodium_0561.png
# calories_0173.png  carbs_0308.png  fat_0437.png     sodium_0562.png
# calories_0174.png  carbs_0309.png  fat_0438.png     sodium_0563.png
# calories_0175.png  carbs_0310.png  fat_0439.png     sodium_0564.png
# calories_0176.png  carbs_0311.png  fat_0440.png     sodium_0565.png
# calories_0177.png  carbs_0312.png  fat_0441.png     sodium_0566.png
# calories_0178.png  carbs_0313.png  fat_0442.png     sodium_0567.png
# calories_0179.png  carbs_0314.png  fat_0443.png     sodium_0568.png
# calories_0180.png  carbs_0315.png  fat_0444.png     sodium_0569.png
# calories_0181.png  carbs_0316.png  fat_0445.png     sodium_0570.png
# calories_0182.png  carbs_0317.png  fat_0446.png     sodium_0571.png
# calories_0183.png  carbs_0318.png  fat_0447.png     sodium_0572.png
# calories_0184.png  carbs_0319.png  fat_0448.png     sodium_0573.png
# calories_0185.png  carbs_0320.png  fat_0449.png     sodium_0574.png
# calories_0186.png  carbs_0321.png  fat_0450.png     sodium_0575.png
# calories_0187.png  carbs_0322.png  fat_0451.png     sodium_0576.png
# calories_0188.png  carbs_0323.png  fat_0452.png     sodium_0577.png
# calories_0189.png  carbs_0324.png  fat_0453.png     sodium_0578.png
# calories_0190.png  carbs_0325.png  fat_0454.png     sodium_0579.png
# calories_0191.png  carbs_0326.png  fat_0455.png     sodium_0580.png
# calories_0192.png  carbs_0327.png  fat_0456.png     sodium_0581.png
# calories_0193.png  carbs_0328.png  fat_0457.png     sodium_0582.png
# calories_0194.png  carbs_0329.png  fat_0458.png     sodium_0583.png
# calories_0195.png  carbs_0330.png  fat_0459.png     sodium_0584.png
# calories_0196.png  carbs_0331.png  fat_0460.png     sodium_0585.png
# calories_0197.png  carbs_0332.png  fat_0461.png     sodium_0586.png
# calories_0198.png  carbs_0333.png  fat_0462.png     sodium_0587.png
# calories_0199.png  carbs_0334.png  fat_0463.png     sodium_0588.png
# calories_0200.png  carbs_0335.png  fat_0464.png     sodium_0589.png
# calories_0201.png  carbs_0336.png  fat_0465.png     sugar_0003.png
# calories_0202.png  carbs_0337.png  fat_0466.png     sugar_0040.png
# calories_0203.png  carbs_0338.png  fat_0467.png     sugar_0042.png
# calories_0204.png  carbs_0339.png  fat_0468.png     sugar_0043.png
# calories_0205.png  carbs_0340.png  fat_0469.png     sugar_0052.png
# calories_0206.png  carbs_0341.png  fat_0470.png     sugar_0055.png
# calories_0207.png  carbs_0342.png  fat_0471.png     sugar_0058.png
# calories_0208.png  carbs_0343.png  fat_0472.png     sugar_0076.png
# calories_0209.png  carbs_0344.png  fat_0473.png     sugar_0078.png
# calories_0210.png  carbs_0345.png  fat_0474.png     sugar_0079.png
# calories_0211.png  carbs_0346.png  fat_0475.png     sugar_0080.png
# calories_0212.png  carbs_0347.png  fat_0476.png     sugar_0081.png
# calories_0213.png  carbs_0348.png  fat_0477.png     sugar_0082.png
# calories_0214.png  carbs_0349.png  fat_0478.png     sugar_0083.png
# calories_0215.png  carbs_0350.png  fat_0479.png     sugar_0084.png
# calories_0216.png  carbs_0351.png  fat_0480.png     sugar_0085.png
# calories_0217.png  carbs_0352.png  fat_0481.png     sugar_0086.png
# calories_0218.png  carbs_0353.png  fat_0482.png     sugar_0087.png
# calories_0219.png  carbs_0354.png  fat_0483.png     sugar_0088.png
# calories_0220.png  carbs_0355.png  fat_0484.png     sugar_0089.png
# calories_0221.png  carbs_0356.png  fat_0485.png     sugar_0090.png
# calories_0222.png  carbs_0357.png  fat_0486.png     sugar_0091.png
# calories_0223.png  carbs_0358.png  fat_0487.png     sugar_0092.png
# calories_0224.png  carbs_0359.png  fat_0488.png     sugar_0093.png
# calories_0225.png  carbs_0360.png  fat_0489.png     sugar_0094.png
# calories_0226.png  carbs_0361.png  fat_0490.png     sugar_0095.png
# calories_0227.png  carbs_0362.png  fat_0491.png     sugar_0096.png
# calories_0228.png  carbs_0363.png  fat_0492.png     sugar_0098.png
# calories_0229.png  carbs_0364.png  fat_0493.png     sugar_0099.png
# calories_0231.png  carbs_0365.png  fat_0494.png     sugar_0100.png
# calories_0232.png  carbs_0366.png  fat_0495.png     sugar_0101.png
# calories_0233.png  carbs_0367.png  fat_0496.png     sugar_0102.png
# calories_0234.png  carbs_0368.png  fat_0497.png     sugar_0103.png
# calories_0235.png  carbs_0369.png  fat_0498.png     sugar_0104.png
# calories_0236.png  carbs_0370.png  fat_0499.png     sugar_0105.png
# calories_0237.png  carbs_0371.png  fat_0500.png     sugar_0106.png
# calories_0238.png  carbs_0372.png  fat_0501.png     sugar_0107.png
# calories_0239.png  carbs_0373.png  fat_0502.png     sugar_0108.png
# calories_0240.png  carbs_0374.png  fat_0503.png     sugar_0109.png
# calories_0241.png  carbs_0375.png  fat_0504.png     sugar_0110.png
# calories_0242.png  carbs_0376.png  fat_0505.png     sugar_0111.png
# calories_0243.png  carbs_0377.png  fat_0506.png     sugar_0112.png
# calories_0245.png  carbs_0378.png  fat_0507.png     sugar_0113.png
# calories_0246.png  carbs_0379.png  fat_0509.png     sugar_0114.png
# calories_0247.png  carbs_0380.png  fat_0510.png     sugar_0115.png
# calories_0248.png  carbs_0381.png  fat_0511.png     sugar_0116.png
# calories_0249.png  carbs_0382.png  fat_0512.png     sugar_0117.png
# calories_0250.png  carbs_0383.png  fat_0513.png     sugar_0118.png
# calories_0251.png  carbs_0384.png  fat_0514.png     sugar_0119.png
# calories_0252.png  carbs_0385.png  fat_0515.png     sugar_0121.png
# calories_0253.png  carbs_0386.png  fat_0516.png     sugar_0122.png
# calories_0254.png  carbs_0387.png  fat_0517.png     sugar_0123.png
# calories_0256.png  carbs_0388.png  fat_0518.png     sugar_0127.png
# calories_0257.png  carbs_0389.png  fat_0519.png     sugar_0128.png
# calories_0258.png  carbs_0390.png  fat_0520.png     sugar_0129.png
# calories_0259.png  carbs_0391.png  fat_0521.png     sugar_0130.png
# calories_0260.png  carbs_0392.png  fat_0522.png     sugar_0131.png
# calories_0262.png  carbs_0393.png  fat_0523.png     sugar_0132.png
# calories_0263.png  carbs_0394.png  fat_0524.png     sugar_0133.png
# calories_0270.png  carbs_0395.png  fat_0525.png     sugar_0134.png
# calories_0271.png  carbs_0396.png  fat_0526.png     sugar_0135.png
# calories_0272.png  carbs_0397.png  fat_0527.png     sugar_0136.png
# calories_0273.png  carbs_0398.png  fat_0528.png     sugar_0137.png
# calories_0274.png  carbs_0399.png  fat_0529.png     sugar_0138.png
# calories_0275.png  carbs_0400.png  fat_0530.png     sugar_0139.png
# calories_0276.png  carbs_0401.png  fat_0531.png     sugar_0140.png
# calories_0277.png  carbs_0402.png  fat_0532.png     sugar_0142.png
# calories_0279.png  carbs_0403.png  fat_0533.png     sugar_0143.png
# calories_0280.png  carbs_0404.png  fat_0534.png     sugar_0144.png
# calories_0281.png  carbs_0405.png  fat_0535.png     sugar_0145.png
# calories_0282.png  carbs_0406.png  fat_0536.png     sugar_0146.png
# calories_0283.png  carbs_0407.png  fat_0537.png     sugar_0147.png
# calories_0284.png  carbs_0408.png  fat_0538.png     sugar_0148.png
# calories_0285.png  carbs_0409.png  fat_0539.png     sugar_0149.png
# calories_0286.png  carbs_0410.png  fat_0540.png     sugar_0150.png
# calories_0287.png  carbs_0411.png  fat_0541.png     sugar_0151.png
# calories_0288.png  carbs_0412.png  fat_0542.png     sugar_0152.png
# calories_0289.png  carbs_0413.png  fat_0543.png     sugar_0153.png
# calories_0290.png  carbs_0414.png  fat_0544.png     sugar_0154.png
# calories_0291.png  carbs_0415.png  fat_0545.png     sugar_0156.png
# calories_0292.png  carbs_0416.png  fat_0546.png     sugar_0159.png
# calories_0293.png  carbs_0417.png  fat_0547.png     sugar_0160.png
# calories_0294.png  carbs_0418.png  fat_0548.png     sugar_0161.png
# calories_0295.png  carbs_0419.png  fat_0549.png     sugar_0162.png
# calories_0296.png  carbs_0420.png  fat_0550.png     sugar_0163.png
# calories_0297.png  carbs_0421.png  fat_0551.png     sugar_0164.png
# calories_0299.png  carbs_0422.png  fat_0552.png     sugar_0165.png
# calories_0300.png  carbs_0423.png  fat_0553.png     sugar_0166.png
# calories_0301.png  carbs_0424.png  fat_0554.png     sugar_0167.png
# calories_0302.png  carbs_0425.png  fat_0555.png     sugar_0168.png
# calories_0303.png  carbs_0426.png  fat_0556.png     sugar_0169.png
# calories_0304.png  carbs_0427.png  fat_0557.png     sugar_0170.png
# calories_0305.png  carbs_0428.png  fat_0558.png     sugar_0171.png
# calories_0306.png  carbs_0429.png  fat_0559.png     sugar_0172.png
# calories_0307.png  carbs_0430.png  fat_0560.png     sugar_0173.png
# calories_0308.png  carbs_0431.png  fat_0561.png     sugar_0174.png
# calories_0309.png  carbs_0432.png  fat_0562.png     sugar_0175.png
# calories_0310.png  carbs_0433.png  fat_0563.png     sugar_0176.png
# calories_0311.png  carbs_0434.png  fat_0564.png     sugar_0177.png
# calories_0312.png  carbs_0435.png  fat_0565.png     sugar_0178.png
# calories_0313.png  carbs_0436.png  fat_0566.png     sugar_0179.png
# calories_0314.png  carbs_0437.png  fat_0567.png     sugar_0180.png
# calories_0315.png  carbs_0438.png  fat_0568.png     sugar_0181.png
# calories_0316.png  carbs_0439.png  fat_0569.png     sugar_0182.png
# calories_0317.png  carbs_0442.png  fat_0570.png     sugar_0183.png
# calories_0318.png  carbs_0443.png  fat_0571.png     sugar_0184.png
# calories_0319.png  carbs_0444.png  fat_0572.png     sugar_0185.png
# calories_0320.png  carbs_0445.png  fat_0573.png     sugar_0186.png
# calories_0321.png  carbs_0446.png  fat_0574.png     sugar_0187.png
# calories_0322.png  carbs_0447.png  fat_0575.png     sugar_0188.png
# calories_0323.png  carbs_0448.png  fat_0576.png     sugar_0189.png
# calories_0324.png  carbs_0449.png  fat_0577.png     sugar_0190.png
# calories_0325.png  carbs_0450.png  fat_0578.png     sugar_0191.png
# calories_0326.png  carbs_0451.png  fat_0579.png     sugar_0192.png
# calories_0327.png  carbs_0452.png  fat_0580.png     sugar_0193.png
# calories_0328.png  carbs_0453.png  fat_0581.png     sugar_0194.png
# calories_0329.png  carbs_0454.png  fat_0582.png     sugar_0195.png
# calories_0330.png  carbs_0455.png  fat_0583.png     sugar_0196.png
# calories_0331.png  carbs_0456.png  fat_0584.png     sugar_0197.png
# calories_0332.png  carbs_0457.png  fat_0585.png     sugar_0198.png
# calories_0333.png  carbs_0458.png  fat_0586.png     sugar_0199.png
# calories_0334.png  carbs_0459.png  fat_0587.png     sugar_0200.png
# calories_0335.png  carbs_0460.png  fat_0588.png     sugar_0201.png
# calories_0336.png  carbs_0461.png  fat_0589.png     sugar_0202.png
# calories_0337.png  carbs_0462.png  fat_0590.png     sugar_0203.png
# calories_0338.png  carbs_0463.png  fat_0591.png     sugar_0204.png
# calories_0339.png  carbs_0464.png  sodium_0010.png  sugar_0205.png
# calories_0340.png  carbs_0465.png  sodium_0040.png  sugar_0206.png
# calories_0341.png  carbs_0466.png  sodium_0041.png  sugar_0207.png
# calories_0342.png  carbs_0467.png  sodium_0044.png  sugar_0208.png
# calories_0343.png  carbs_0468.png  sodium_0055.png  sugar_0209.png
# calories_0344.png  carbs_0469.png  sodium_0060.png  sugar_0210.png
# calories_0345.png  carbs_0470.png  sodium_0076.png  sugar_0211.png
# calories_0346.png  carbs_0471.png  sodium_0078.png  sugar_0212.png
# calories_0347.png  carbs_0472.png  sodium_0079.png  sugar_0213.png
# calories_0348.png  carbs_0473.png  sodium_0080.png  sugar_0214.png
# calories_0349.png  carbs_0475.png  sodium_0081.png  sugar_0215.png
# calories_0350.png  carbs_0476.png  sodium_0082.png  sugar_0216.png
# calories_0351.png  carbs_0477.png  sodium_0083.png  sugar_0217.png
# calories_0352.png  carbs_0478.png  sodium_0084.png  sugar_0218.png
# calories_0353.png  carbs_0479.png  sodium_0086.png  sugar_0219.png
# calories_0354.png  carbs_0480.png  sodium_0087.png  sugar_0220.png
# calories_0355.png  carbs_0481.png  sodium_0088.png  sugar_0221.png
# calories_0356.png  carbs_0482.png  sodium_0089.png  sugar_0222.png
# calories_0357.png  carbs_0483.png  sodium_0090.png  sugar_0223.png
# calories_0358.png  carbs_0484.png  sodium_0091.png  sugar_0224.png
# calories_0359.png  carbs_0485.png  sodium_0093.png  sugar_0225.png
# calories_0360.png  carbs_0486.png  sodium_0095.png  sugar_0226.png
# calories_0361.png  carbs_0487.png  sodium_0096.png  sugar_0227.png
# calories_0362.png  carbs_0488.png  sodium_0097.png  sugar_0228.png
# calories_0363.png  carbs_0489.png  sodium_0098.png  sugar_0229.png
# calories_0364.png  carbs_0490.png  sodium_0099.png  sugar_0230.png
# calories_0365.png  carbs_0491.png  sodium_0100.png  sugar_0231.png
# calories_0366.png  carbs_0492.png  sodium_0101.png  sugar_0232.png
# calories_0367.png  carbs_0493.png  sodium_0102.png  sugar_0233.png
# calories_0368.png  carbs_0494.png  sodium_0103.png  sugar_0234.png
# calories_0369.png  carbs_0495.png  sodium_0104.png  sugar_0235.png
# calories_0370.png  carbs_0496.png  sodium_0105.png  sugar_0236.png
# calories_0371.png  carbs_0497.png  sodium_0106.png  sugar_0237.png
# calories_0372.png  carbs_0498.png  sodium_0107.png  sugar_0238.png
# calories_0373.png  carbs_0499.png  sodium_0108.png  sugar_0239.png
# calories_0374.png  carbs_0501.png  sodium_0109.png  sugar_0240.png
# calories_0375.png  carbs_0502.png  sodium_0110.png  sugar_0241.png
# calories_0376.png  carbs_0503.png  sodium_0111.png  sugar_0242.png
# calories_0377.png  carbs_0504.png  sodium_0113.png  sugar_0243.png
# calories_0378.png  carbs_0505.png  sodium_0114.png  sugar_0244.png
# calories_0379.png  carbs_0506.png  sodium_0115.png  sugar_0245.png
# calories_0380.png  carbs_0507.png  sodium_0116.png  sugar_0246.png
# calories_0381.png  carbs_0508.png  sodium_0117.png  sugar_0247.png
# calories_0382.png  carbs_0509.png  sodium_0118.png  sugar_0248.png
# calories_0383.png  carbs_0510.png  sodium_0120.png  sugar_0249.png
# calories_0384.png  carbs_0511.png  sodium_0121.png  sugar_0250.png
# calories_0385.png  carbs_0512.png  sodium_0122.png  sugar_0251.png
# calories_0386.png  carbs_0513.png  sodium_0123.png  sugar_0252.png
# calories_0387.png  carbs_0514.png  sodium_0127.png  sugar_0253.png
# calories_0388.png  carbs_0515.png  sodium_0128.png  sugar_0254.png
# calories_0389.png  carbs_0516.png  sodium_0129.png  sugar_0255.png
# calories_0390.png  carbs_0517.png  sodium_0130.png  sugar_0256.png
# calories_0391.png  carbs_0518.png  sodium_0131.png  sugar_0258.png
# calories_0392.png  carbs_0519.png  sodium_0132.png  sugar_0259.png
# calories_0393.png  carbs_0520.png  sodium_0133.png  sugar_0260.png
# calories_0394.png  carbs_0521.png  sodium_0134.png  sugar_0261.png
# calories_0395.png  carbs_0522.png  sodium_0135.png  sugar_0262.png
# calories_0396.png  carbs_0523.png  sodium_0136.png  sugar_0264.png
# calories_0397.png  carbs_0524.png  sodium_0137.png  sugar_0265.png
# calories_0398.png  carbs_0525.png  sodium_0138.png  sugar_0272.png
# calories_0399.png  carbs_0526.png  sodium_0139.png  sugar_0273.png
# calories_0400.png  carbs_0527.png  sodium_0142.png  sugar_0274.png
# calories_0401.png  carbs_0528.png  sodium_0143.png  sugar_0275.png
# calories_0402.png  carbs_0529.png  sodium_0144.png  sugar_0276.png
# calories_0403.png  carbs_0530.png  sodium_0145.png  sugar_0277.png
# calories_0404.png  carbs_0531.png  sodium_0146.png  sugar_0278.png
# calories_0405.png  carbs_0532.png  sodium_0147.png  sugar_0279.png
# calories_0406.png  carbs_0533.png  sodium_0148.png  sugar_0280.png
# calories_0407.png  carbs_0534.png  sodium_0149.png  sugar_0281.png
# calories_0408.png  carbs_0535.png  sodium_0150.png  sugar_0282.png
# calories_0409.png  carbs_0536.png  sodium_0151.png  sugar_0283.png
# calories_0410.png  carbs_0537.png  sodium_0152.png  sugar_0284.png
# calories_0411.png  carbs_0538.png  sodium_0153.png  sugar_0285.png
# calories_0412.png  carbs_0539.png  sodium_0154.png  sugar_0286.png
# calories_0413.png  carbs_0540.png  sodium_0156.png  sugar_0287.png
# calories_0414.png  carbs_0541.png  sodium_0157.png  sugar_0288.png
# calories_0415.png  carbs_0542.png  sodium_0158.png  sugar_0289.png
# calories_0416.png  carbs_0543.png  sodium_0159.png  sugar_0290.png
# calories_0417.png  carbs_0544.png  sodium_0160.png  sugar_0291.png
# calories_0418.png  carbs_0545.png  sodium_0161.png  sugar_0292.png
# calories_0419.png  carbs_0546.png  sodium_0162.png  sugar_0293.png
# calories_0420.png  carbs_0547.png  sodium_0163.png  sugar_0294.png
# calories_0421.png  carbs_0548.png  sodium_0164.png  sugar_0295.png
# calories_0422.png  carbs_0549.png  sodium_0165.png  sugar_0296.png
# calories_0423.png  carbs_0550.png  sodium_0166.png  sugar_0297.png
# calories_0424.png  carbs_0551.png  sodium_0167.png  sugar_0298.png
# calories_0425.png  carbs_0552.png  sodium_0168.png  sugar_0299.png
# calories_0426.png  carbs_0553.png  sodium_0169.png  sugar_0301.png
# calories_0427.png  carbs_0554.png  sodium_0170.png  sugar_0302.png
# calories_0428.png  carbs_0555.png  sodium_0171.png  sugar_0303.png
# calories_0429.png  carbs_0556.png  sodium_0172.png  sugar_0304.png
# calories_0430.png  carbs_0557.png  sodium_0173.png  sugar_0305.png
# calories_0431.png  carbs_0558.png  sodium_0174.png  sugar_0306.png
# calories_0432.png  carbs_0559.png  sodium_0175.png  sugar_0307.png
# calories_0433.png  carbs_0560.png  sodium_0176.png  sugar_0308.png
# calories_0434.png  carbs_0561.png  sodium_0177.png  sugar_0309.png
# calories_0435.png  carbs_0562.png  sodium_0178.png  sugar_0310.png
# calories_0436.png  carbs_0563.png  sodium_0179.png  sugar_0311.png
# calories_0437.png  carbs_0564.png  sodium_0180.png  sugar_0312.png
# calories_0438.png  carbs_0565.png  sodium_0181.png  sugar_0313.png
# calories_0439.png  carbs_0566.png  sodium_0182.png  sugar_0314.png
# calories_0440.png  carbs_0567.png  sodium_0183.png  sugar_0315.png
# calories_0441.png  carbs_0568.png  sodium_0184.png  sugar_0316.png
# calories_0442.png  carbs_0569.png  sodium_0185.png  sugar_0317.png
# calories_0443.png  carbs_0570.png  sodium_0186.png  sugar_0318.png
# calories_0444.png  carbs_0571.png  sodium_0187.png  sugar_0319.png
# calories_0445.png  carbs_0572.png  sodium_0188.png  sugar_0320.png
# calories_0446.png  carbs_0573.png  sodium_0189.png  sugar_0321.png
# calories_0447.png  carbs_0574.png  sodium_0190.png  sugar_0322.png
# calories_0448.png  carbs_0575.png  sodium_0191.png  sugar_0323.png
# calories_0449.png  carbs_0576.png  sodium_0192.png  sugar_0324.png
# calories_0450.png  carbs_0577.png  sodium_0193.png  sugar_0325.png
# calories_0451.png  carbs_0578.png  sodium_0194.png  sugar_0326.png
# calories_0452.png  carbs_0579.png  sodium_0195.png  sugar_0327.png
# calories_0453.png  carbs_0580.png  sodium_0196.png  sugar_0328.png
# calories_0454.png  carbs_0581.png  sodium_0197.png  sugar_0329.png
# calories_0455.png  fat_0002.png    sodium_0198.png  sugar_0330.png
# calories_0456.png  fat_0003.png    sodium_0199.png  sugar_0331.png
# calories_0457.png  fat_0010.png    sodium_0200.png  sugar_0332.png
# calories_0458.png  fat_0040.png    sodium_0201.png  sugar_0333.png
# calories_0459.png  fat_0041.png    sodium_0202.png  sugar_0334.png
# calories_0460.png  fat_0042.png    sodium_0203.png  sugar_0335.png
# calories_0461.png  fat_0043.png    sodium_0204.png  sugar_0336.png
# calories_0462.png  fat_0044.png    sodium_0205.png  sugar_0337.png
# calories_0463.png  fat_0055.png    sodium_0206.png  sugar_0338.png
# calories_0464.png  fat_0058.png    sodium_0207.png  sugar_0339.png
# calories_0465.png  fat_0059.png    sodium_0208.png  sugar_0340.png
# calories_0466.png  fat_0076.png    sodium_0209.png  sugar_0341.png
# calories_0467.png  fat_0078.png    sodium_0210.png  sugar_0342.png
# calories_0468.png  fat_0079.png    sodium_0211.png  sugar_0343.png
# calories_0469.png  fat_0080.png    sodium_0212.png  sugar_0344.png
# calories_0470.png  fat_0081.png    sodium_0213.png  sugar_0345.png
# calories_0471.png  fat_0082.png    sodium_0214.png  sugar_0346.png
# calories_0472.png  fat_0083.png    sodium_0215.png  sugar_0347.png
# calories_0473.png  fat_0084.png    sodium_0216.png  sugar_0348.png
# calories_0474.png  fat_0085.png    sodium_0217.png  sugar_0349.png
# calories_0475.png  fat_0086.png    sodium_0218.png  sugar_0350.png
# calories_0476.png  fat_0087.png    sodium_0219.png  sugar_0351.png
# calories_0477.png  fat_0088.png    sodium_0220.png  sugar_0352.png
# calories_0478.png  fat_0089.png    sodium_0221.png  sugar_0354.png
# calories_0479.png  fat_0090.png    sodium_0222.png  sugar_0355.png
# calories_0480.png  fat_0091.png    sodium_0223.png  sugar_0356.png
# calories_0481.png  fat_0092.png    sodium_0224.png  sugar_0357.png
# calories_0482.png  fat_0093.png    sodium_0225.png  sugar_0358.png
# calories_0483.png  fat_0094.png    sodium_0226.png  sugar_0359.png
# calories_0484.png  fat_0095.png    sodium_0227.png  sugar_0360.png
# calories_0485.png  fat_0096.png    sodium_0228.png  sugar_0361.png
# calories_0486.png  fat_0097.png    sodium_0229.png  sugar_0362.png
# calories_0487.png  fat_0098.png    sodium_0230.png  sugar_0363.png
# calories_0488.png  fat_0099.png    sodium_0231.png  sugar_0364.png
# calories_0489.png  fat_0101.png    sodium_0232.png  sugar_0365.png
# calories_0490.png  fat_0102.png    sodium_0233.png  sugar_0366.png
# calories_0491.png  fat_0103.png    sodium_0234.png  sugar_0367.png
# calories_0492.png  fat_0104.png    sodium_0235.png  sugar_0368.png
# calories_0493.png  fat_0105.png    sodium_0236.png  sugar_0369.png
# calories_0494.png  fat_0106.png    sodium_0237.png  sugar_0370.png
# calories_0495.png  fat_0107.png    sodium_0238.png  sugar_0371.png
# calories_0496.png  fat_0108.png    sodium_0239.png  sugar_0372.png
# calories_0497.png  fat_0109.png    sodium_0240.png  sugar_0373.png
# calories_0498.png  fat_0110.png    sodium_0242.png  sugar_0374.png
# calories_0499.png  fat_0111.png    sodium_0243.png  sugar_0375.png
# calories_0500.png  fat_0112.png    sodium_0244.png  sugar_0376.png
# calories_0501.png  fat_0113.png    sodium_0245.png  sugar_0377.png
# calories_0502.png  fat_0114.png    sodium_0246.png  sugar_0378.png
# calories_0503.png  fat_0115.png    sodium_0247.png  sugar_0379.png
# calories_0505.png  fat_0116.png    sodium_0248.png  sugar_0380.png
# calories_0506.png  fat_0117.png    sodium_0249.png  sugar_0381.png
# calories_0507.png  fat_0118.png    sodium_0250.png  sugar_0382.png
# calories_0508.png  fat_0119.png    sodium_0251.png  sugar_0383.png
# calories_0509.png  fat_0120.png    sodium_0252.png  sugar_0384.png
# calories_0510.png  fat_0121.png    sodium_0253.png  sugar_0385.png
# calories_0511.png  fat_0122.png    sodium_0254.png  sugar_0386.png
# calories_0512.png  fat_0123.png    sodium_0255.png  sugar_0387.png
# calories_0513.png  fat_0127.png    sodium_0256.png  sugar_0388.png
# calories_0514.png  fat_0128.png    sodium_0257.png  sugar_0389.png
# calories_0515.png  fat_0129.png    sodium_0259.png  sugar_0390.png
# calories_0516.png  fat_0130.png    sodium_0260.png  sugar_0391.png
# calories_0517.png  fat_0131.png    sodium_0261.png  sugar_0392.png
# calories_0518.png  fat_0132.png    sodium_0262.png  sugar_0393.png
# calories_0519.png  fat_0133.png    sodium_0263.png  sugar_0394.png
# calories_0520.png  fat_0134.png    sodium_0265.png  sugar_0395.png
# calories_0521.png  fat_0136.png    sodium_0266.png  sugar_0396.png
# calories_0522.png  fat_0137.png    sodium_0273.png  sugar_0397.png
# calories_0523.png  fat_0138.png    sodium_0274.png  sugar_0398.png
# calories_0524.png  fat_0139.png    sodium_0275.png  sugar_0399.png
# calories_0525.png  fat_0142.png    sodium_0276.png  sugar_0400.png
# calories_0526.png  fat_0143.png    sodium_0277.png  sugar_0401.png
# calories_0527.png  fat_0144.png    sodium_0278.png  sugar_0402.png
# calories_0528.png  fat_0145.png    sodium_0279.png  sugar_0403.png
# calories_0529.png  fat_0146.png    sodium_0280.png  sugar_0404.png
# calories_0530.png  fat_0147.png    sodium_0281.png  sugar_0405.png
# calories_0531.png  fat_0148.png    sodium_0282.png  sugar_0406.png
# calories_0532.png  fat_0149.png    sodium_0283.png  sugar_0407.png
# calories_0533.png  fat_0150.png    sodium_0284.png  sugar_0408.png
# calories_0534.png  fat_0151.png    sodium_0285.png  sugar_0409.png
# calories_0535.png  fat_0152.png    sodium_0286.png  sugar_0410.png
# calories_0536.png  fat_0153.png    sodium_0287.png  sugar_0411.png
# calories_0537.png  fat_0154.png    sodium_0288.png  sugar_0412.png
# calories_0538.png  fat_0156.png    sodium_0289.png  sugar_0413.png
# calories_0539.png  fat_0157.png    sodium_0290.png  sugar_0414.png
# calories_0540.png  fat_0158.png    sodium_0291.png  sugar_0415.png
# calories_0541.png  fat_0159.png    sodium_0292.png  sugar_0416.png
# calories_0542.png  fat_0160.png    sodium_0293.png  sugar_0417.png
# calories_0543.png  fat_0161.png    sodium_0294.png  sugar_0418.png
# calories_0544.png  fat_0162.png    sodium_0295.png  sugar_0419.png
# calories_0545.png  fat_0163.png    sodium_0296.png  sugar_0420.png
# calories_0546.png  fat_0164.png    sodium_0297.png  sugar_0421.png
# calories_0547.png  fat_0165.png    sodium_0298.png  sugar_0422.png
# calories_0548.png  fat_0166.png    sodium_0299.png  sugar_0423.png
# calories_0549.png  fat_0167.png    sodium_0300.png  sugar_0424.png
# calories_0550.png  fat_0168.png    sodium_0302.png  sugar_0425.png
# calories_0551.png  fat_0169.png    sodium_0303.png  sugar_0426.png
# calories_0552.png  fat_0170.png    sodium_0304.png  sugar_0427.png
# calories_0553.png  fat_0171.png    sodium_0305.png  sugar_0428.png
# calories_0554.png  fat_0172.png    sodium_0306.png  sugar_0429.png
# calories_0555.png  fat_0173.png    sodium_0307.png  sugar_0430.png
# calories_0556.png  fat_0174.png    sodium_0308.png  sugar_0431.png
# calories_0557.png  fat_0175.png    sodium_0309.png  sugar_0432.png
# calories_0558.png  fat_0176.png    sodium_0310.png  sugar_0433.png
# calories_0559.png  fat_0177.png    sodium_0311.png  sugar_0434.png
# calories_0560.png  fat_0178.png    sodium_0312.png  sugar_0435.png
# calories_0561.png  fat_0179.png    sodium_0313.png  sugar_0436.png
# calories_0562.png  fat_0180.png    sodium_0314.png  sugar_0437.png
# calories_0563.png  fat_0181.png    sodium_0315.png  sugar_0438.png
# calories_0564.png  fat_0182.png    sodium_0316.png  sugar_0439.png
# calories_0565.png  fat_0183.png    sodium_0317.png  sugar_0440.png
# calories_0566.png  fat_0184.png    sodium_0318.png  sugar_0441.png
# calories_0567.png  fat_0185.png    sodium_0319.png  sugar_0442.png
# calories_0568.png  fat_0186.png    sodium_0320.png  sugar_0443.png
# calories_0569.png  fat_0187.png    sodium_0321.png  sugar_0444.png
# calories_0570.png  fat_0188.png    sodium_0322.png  sugar_0445.png
# calories_0571.png  fat_0189.png    sodium_0323.png  sugar_0446.png
# calories_0572.png  fat_0190.png    sodium_0324.png  sugar_0447.png
# calories_0573.png  fat_0191.png    sodium_0325.png  sugar_0448.png
# calories_0574.png  fat_0192.png    sodium_0326.png  sugar_0449.png
# calories_0575.png  fat_0193.png    sodium_0327.png  sugar_0450.png
# calories_0576.png  fat_0194.png    sodium_0328.png  sugar_0451.png
# calories_0577.png  fat_0195.png    sodium_0329.png  sugar_0452.png
# calories_0578.png  fat_0196.png    sodium_0330.png  sugar_0453.png
# calories_0579.png  fat_0197.png    sodium_0331.png  sugar_0454.png
# calories_0580.png  fat_0198.png    sodium_0332.png  sugar_0455.png
# calories_0581.png  fat_0199.png    sodium_0333.png  sugar_0456.png
# calories_0582.png  fat_0200.png    sodium_0334.png  sugar_0457.png
# calories_0583.png  fat_0201.png    sodium_0335.png  sugar_0458.png
# calories_0584.png  fat_0202.png    sodium_0336.png  sugar_0459.png
# calories_0585.png  fat_0203.png    sodium_0337.png  sugar_0460.png
# calories_0586.png  fat_0204.png    sodium_0338.png  sugar_0461.png
# carbs_0002.png	   fat_0205.png    sodium_0339.png  sugar_0462.png
# carbs_0010.png	   fat_0206.png    sodium_0340.png  sugar_0463.png
# carbs_0040.png	   fat_0207.png    sodium_0341.png  sugar_0464.png
# carbs_0041.png	   fat_0208.png    sodium_0342.png  sugar_0465.png
# carbs_0043.png	   fat_0209.png    sodium_0343.png  sugar_0466.png
# carbs_0044.png	   fat_0210.png    sodium_0344.png  sugar_0467.png
# carbs_0076.png	   fat_0211.png    sodium_0345.png  sugar_0468.png
# carbs_0078.png	   fat_0212.png    sodium_0346.png  sugar_0469.png
# carbs_0079.png	   fat_0213.png    sodium_0347.png  sugar_0470.png
# carbs_0080.png	   fat_0214.png    sodium_0348.png  sugar_0471.png
# carbs_0081.png	   fat_0215.png    sodium_0349.png  sugar_0472.png
# carbs_0082.png	   fat_0216.png    sodium_0350.png  sugar_0473.png
# carbs_0083.png	   fat_0217.png    sodium_0351.png  sugar_0474.png
# carbs_0084.png	   fat_0218.png    sodium_0352.png  sugar_0475.png
# carbs_0085.png	   fat_0219.png    sodium_0353.png  sugar_0476.png
# carbs_0086.png	   fat_0220.png    sodium_0354.png  sugar_0477.png
# carbs_0087.png	   fat_0221.png    sodium_0355.png  sugar_0478.png
# carbs_0088.png	   fat_0222.png    sodium_0356.png  sugar_0479.png
# carbs_0089.png	   fat_0223.png    sodium_0357.png  sugar_0480.png
# carbs_0090.png	   fat_0224.png    sodium_0358.png  sugar_0481.png
# carbs_0091.png	   fat_0225.png    sodium_0359.png  sugar_0482.png
# carbs_0092.png	   fat_0226.png    sodium_0360.png  sugar_0483.png
# carbs_0093.png	   fat_0227.png    sodium_0361.png  sugar_0484.png
# carbs_0094.png	   fat_0228.png    sodium_0362.png  sugar_0485.png
# carbs_0095.png	   fat_0229.png    sodium_0363.png  sugar_0486.png
# carbs_0096.png	   fat_0230.png    sodium_0364.png  sugar_0487.png
# carbs_0097.png	   fat_0231.png    sodium_0365.png  sugar_0488.png
# carbs_0098.png	   fat_0232.png    sodium_0366.png  sugar_0489.png
# carbs_0099.png	   fat_0233.png    sodium_0367.png  sugar_0490.png
# carbs_0100.png	   fat_0234.png    sodium_0368.png  sugar_0491.png
# carbs_0101.png	   fat_0235.png    sodium_0369.png  sugar_0492.png
# carbs_0102.png	   fat_0236.png    sodium_0370.png  sugar_0493.png
# carbs_0103.png	   fat_0237.png    sodium_0371.png  sugar_0494.png
# carbs_0104.png	   fat_0238.png    sodium_0372.png  sugar_0495.png
# carbs_0105.png	   fat_0239.png    sodium_0373.png  sugar_0496.png
# carbs_0106.png	   fat_0240.png    sodium_0374.png  sugar_0497.png
# carbs_0107.png	   fat_0241.png    sodium_0375.png  sugar_0498.png
# carbs_0108.png	   fat_0242.png    sodium_0376.png  sugar_0499.png
# carbs_0109.png	   fat_0243.png    sodium_0377.png  sugar_0500.png
# carbs_0110.png	   fat_0244.png    sodium_0378.png  sugar_0501.png
# carbs_0112.png	   fat_0245.png    sodium_0379.png  sugar_0502.png
# carbs_0113.png	   fat_0246.png    sodium_0380.png  sugar_0503.png
# carbs_0114.png	   fat_0247.png    sodium_0381.png  sugar_0504.png
# carbs_0115.png	   fat_0248.png    sodium_0382.png  sugar_0505.png
# carbs_0116.png	   fat_0249.png    sodium_0383.png  sugar_0507.png
# carbs_0117.png	   fat_0250.png    sodium_0384.png  sugar_0508.png
# carbs_0118.png	   fat_0251.png    sodium_0385.png  sugar_0509.png
# carbs_0119.png	   fat_0252.png    sodium_0386.png  sugar_0510.png
# carbs_0120.png	   fat_0253.png    sodium_0387.png  sugar_0511.png
# carbs_0121.png	   fat_0254.png    sodium_0388.png  sugar_0512.png
# carbs_0122.png	   fat_0255.png    sodium_0389.png  sugar_0513.png
# carbs_0126.png	   fat_0256.png    sodium_0390.png  sugar_0514.png
# carbs_0127.png	   fat_0258.png    sodium_0391.png  sugar_0515.png
# carbs_0128.png	   fat_0259.png    sodium_0392.png  sugar_0516.png
# carbs_0129.png	   fat_0260.png    sodium_0393.png  sugar_0517.png
# carbs_0130.png	   fat_0261.png    sodium_0394.png  sugar_0518.png
# carbs_0131.png	   fat_0262.png    sodium_0395.png  sugar_0519.png
# carbs_0132.png	   fat_0264.png    sodium_0396.png  sugar_0520.png
# carbs_0133.png	   fat_0265.png    sodium_0397.png  sugar_0521.png
# carbs_0134.png	   fat_0272.png    sodium_0398.png  sugar_0522.png
# carbs_0135.png	   fat_0273.png    sodium_0399.png  sugar_0523.png
# carbs_0136.png	   fat_0274.png    sodium_0400.png  sugar_0524.png
# carbs_0137.png	   fat_0275.png    sodium_0401.png  sugar_0525.png
# carbs_0138.png	   fat_0276.png    sodium_0402.png  sugar_0526.png
# carbs_0140.png	   fat_0277.png    sodium_0403.png  sugar_0527.png
# carbs_0141.png	   fat_0278.png    sodium_0404.png  sugar_0528.png
# carbs_0142.png	   fat_0279.png    sodium_0405.png  sugar_0529.png
# carbs_0143.png	   fat_0280.png    sodium_0406.png  sugar_0530.png
# carbs_0144.png	   fat_0281.png    sodium_0407.png  sugar_0531.png
# carbs_0145.png	   fat_0282.png    sodium_0408.png  sugar_0532.png
# carbs_0146.png	   fat_0283.png    sodium_0409.png  sugar_0533.png
# carbs_0147.png	   fat_0284.png    sodium_0410.png  sugar_0534.png
# carbs_0148.png	   fat_0285.png    sodium_0411.png  sugar_0535.png
# carbs_0149.png	   fat_0286.png    sodium_0412.png  sugar_0536.png
# carbs_0150.png	   fat_0287.png    sodium_0413.png  sugar_0537.png
# carbs_0151.png	   fat_0288.png    sodium_0414.png  sugar_0538.png
# carbs_0152.png	   fat_0289.png    sodium_0415.png  sugar_0539.png
# carbs_0153.png	   fat_0290.png    sodium_0416.png  sugar_0540.png
# carbs_0155.png	   fat_0291.png    sodium_0417.png  sugar_0541.png
# carbs_0156.png	   fat_0292.png    sodium_0418.png  sugar_0542.png
# carbs_0157.png	   fat_0294.png    sodium_0419.png  sugar_0543.png
# carbs_0158.png	   fat_0295.png    sodium_0420.png  sugar_0544.png
# carbs_0159.png	   fat_0296.png    sodium_0421.png  sugar_0545.png
# carbs_0160.png	   fat_0297.png    sodium_0422.png  sugar_0546.png
# carbs_0161.png	   fat_0298.png    sodium_0423.png  sugar_0547.png
# carbs_0162.png	   fat_0299.png    sodium_0424.png  sugar_0548.png
# carbs_0163.png	   fat_0301.png    sodium_0425.png  sugar_0549.png
# carbs_0164.png	   fat_0302.png    sodium_0426.png  sugar_0550.png
# carbs_0165.png	   fat_0303.png    sodium_0427.png  sugar_0551.png
# carbs_0166.png	   fat_0304.png    sodium_0428.png  sugar_0552.png
# carbs_0167.png	   fat_0305.png    sodium_0429.png  sugar_0553.png
# carbs_0168.png	   fat_0306.png    sodium_0430.png  sugar_0554.png
# carbs_0169.png	   fat_0307.png    sodium_0431.png  sugar_0555.png
# carbs_0170.png	   fat_0308.png    sodium_0432.png  sugar_0556.png
# carbs_0171.png	   fat_0309.png    sodium_0433.png  sugar_0557.png
# carbs_0172.png	   fat_0310.png    sodium_0434.png  sugar_0558.png
# carbs_0173.png	   fat_0311.png    sodium_0435.png  sugar_0559.png
# carbs_0174.png	   fat_0312.png    sodium_0436.png  sugar_0560.png
# carbs_0175.png	   fat_0313.png    sodium_0437.png  sugar_0561.png
# carbs_0176.png	   fat_0314.png    sodium_0438.png  sugar_0562.png
# carbs_0177.png	   fat_0315.png    sodium_0439.png  sugar_0563.png
# carbs_0178.png	   fat_0316.png    sodium_0440.png  sugar_0564.png
# carbs_0179.png	   fat_0317.png    sodium_0441.png  sugar_0565.png
# carbs_0180.png	   fat_0318.png    sodium_0442.png  sugar_0566.png
# carbs_0181.png	   fat_0319.png    sodium_0443.png  sugar_0567.png
# carbs_0182.png	   fat_0320.png    sodium_0444.png  sugar_0568.png
# carbs_0183.png	   fat_0321.png    sodium_0445.png  sugar_0569.png
# carbs_0184.png	   fat_0322.png    sodium_0446.png  sugar_0570.png
# carbs_0185.png	   fat_0323.png    sodium_0447.png  sugar_0571.png
# carbs_0186.png	   fat_0324.png    sodium_0448.png  sugar_0572.png
# carbs_0187.png	   fat_0325.png    sodium_0449.png  sugar_0573.png
# carbs_0188.png	   fat_0326.png    sodium_0450.png  sugar_0574.png
# carbs_0189.png	   fat_0327.png    sodium_0451.png  sugar_0575.png
# carbs_0190.png	   fat_0328.png    sodium_0452.png  sugar_0576.png
# carbs_0191.png	   fat_0329.png    sodium_0453.png  sugar_0577.png
# carbs_0192.png	   fat_0330.png    sodium_0454.png  sugar_0578.png
# carbs_0193.png	   fat_0331.png    sodium_0455.png  sugar_0579.png
# carbs_0194.png	   fat_0332.png    sodium_0456.png  sugar_0580.png
# carbs_0195.png	   fat_0333.png    sodium_0457.png  sugar_0581.png
# carbs_0196.png	   fat_0334.png    sodium_0458.png  sugar_0582.png
# carbs_0197.png	   fat_0335.png    sodium_0459.png  sugar_0583.png
# carbs_0198.png	   fat_0336.png    sodium_0460.png  sugar_0584.png
# carbs_0199.png	   fat_0337.png    sodium_0461.png  sugar_0585.png
# carbs_0200.png	   fat_0338.png    sodium_0462.png  sugar_0586.png
# carbs_0201.png	   fat_0339.png    sodium_0463.png  sugar_0587.png
# carbs_0202.png	   fat_0340.png    sodium_0464.png  sugar_0588.png
# carbs_0203.png	   fat_0341.png    sodium_0465.png
# carbs_0204.png	   fat_0342.png    sodium_0466.png
#
# /content/drive/MyDrive/ocr_crop_v3/valid:
# valid.xlsx

# %%
# ── Scan semua gambar ─────────────────────────────────────────
img_files = [
    f for f in os.listdir(IMG_DIR)
    if Path(f).suffix.lower() in IMG_EXTS
]
print(f'🖼️  Total gambar ditemukan: {len(img_files)}')
print(f'📋 Total baris CSV label : {len(df_label)}')
# Out:
# 🖼️  Total gambar ditemukan: 2490
# 📋 Total baris CSV label : 2490

# %% [markdown]
# ## 2. Analisis Kualitas CSV

# %%
print('='*55)
print('  ANALISIS KUALITAS CSV LABEL')
print('='*55)

total    = len(df_label)
missing  = df_label['text'].isna().sum()
empty    = (df_label['text'].astype(str).str.strip() == '').sum()
dup_rows = df_label.duplicated(subset=['file_name']).sum()
dup_text = df_label.duplicated(subset=['text']).sum()
short    = (df_label['text'].astype(str).str.len() < 3).sum()

print(f'  Total baris          : {total}')
print(f'  Missing (NaN)        : {missing}  ({missing/total*100:.1f}%)')
print(f'  Teks kosong          : {empty}  ({empty/total*100:.1f}%)')
print(f'  Duplikat file_name   : {dup_rows}')
print(f'  Duplikat teks        : {dup_text}')
print(f'  Teks sangat pendek   : {short}  (< 3 karakter)')

# Panjang teks
df_label['text_len'] = df_label['text'].astype(str).str.len()
print(f'\n  Panjang teks (karakter):')
print(f'  Min    : {df_label["text_len"].min()}')
print(f'  Max    : {df_label["text_len"].max()}')
print(f'  Median : {df_label["text_len"].median():.0f}')
print(f'  Mean   : {df_label["text_len"].mean():.1f}')
# Out:
# =======================================================
#   ANALISIS KUALITAS CSV LABEL
# =======================================================
#   Total baris          : 2490
#   Missing (NaN)        : 0  (0.0%)
#   Teks kosong          : 0  (0.0%)
#   Duplikat file_name   : 0
#   Duplikat teks        : 1768
#   Teks sangat pendek   : 0  (< 3 karakter)
#
#   Panjang teks (karakter):
#   Min    : 6
#   Max    : 50
#   Median : 22
#   Mean   : 25.3

# %%
# Ekstrak kelas dari file_name (prefix sebelum '_')
df_label['class'] = df_label['file_name'].astype(str).apply(
    lambda x: x.split('_')[0].lower()
)

print('Distribusi kelas dalam CSV:')
print(df_label['class'].value_counts().to_string())
# Out:
# Distribusi kelas dalam CSV:
# class
# fat         507
# sugar       499
# sodium      497
# calories    495
# carbs       492

# %% [markdown]
# ## 3. Analisis Kualitas Gambar

# %%
print('Mengekstrak fitur gambar... (mungkin 2-5 menit)\n')

def laplacian_variance(gray_img):
    """Mengukur ketajaman gambar. Nilai rendah = blur."""
    return cv2.Laplacian(gray_img, cv2.CV_64F).var()

def mean_brightness(gray_img):
    return gray_img.mean()

records = []
corrupt = []

for fname in tqdm(img_files, desc='Scan Gambar'):
    fpath = os.path.join(IMG_DIR, fname)
    img   = cv2.imread(fpath)

    if img is None:
        corrupt.append(fname)
        continue

    h, w  = img.shape[:2]
    gray  = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    class_name = fname.split('_')[0].lower()

    records.append({
        'file_name'  : fname,
        'class'      : class_name,
        'width'      : w,
        'height'     : h,
        'aspect_ratio': round(w / h, 3),
        'megapixels' : round((w * h) / 1e6, 4),
        'blur_score' : round(laplacian_variance(gray), 2),
        'brightness' : round(mean_brightness(gray), 2),
    })

df_img = pd.DataFrame(records)

print(f'\n✅ Selesai. Total valid: {len(df_img)} | Corrupt/gagal baca: {len(corrupt)}')
if corrupt:
    print(f'   File corrupt: {corrupt[:5]}...')
df_img.describe().round(2)
# Out:
# Mengekstrak fitur gambar... (mungkin 2-5 menit)
# Scan Gambar:   0%|          | 0/2490 [00:00<?, ?it/s]
# ✅ Selesai. Total valid: 2490 | Corrupt/gagal baca: 0
#          width   height  aspect_ratio  megapixels  blur_score  brightness
# count  2490.00  2490.00       2490.00     2490.00     2490.00     2490.00
# mean    948.85   104.79          9.35        0.11      324.94      155.36
# std     424.88    42.18          3.10        0.09      710.11       37.78
# min     173.00    22.00          2.96        0.00        6.12       26.86
# 25%     626.00    77.00          7.08        0.05       65.78      134.11
# 50%     871.00    96.00          8.92        0.09      164.43      158.53
# 75%    1184.75   126.00         11.29        0.14      345.84      181.70
# max    2977.00   320.00         22.76        0.69    13388.69      240.34

# %% [markdown]
# ## 4. Konsistensi CSV ↔ Gambar

# %%
csv_files_set = set(df_label['file_name'].astype(str))
img_files_set = set(img_files)

in_csv_not_img = csv_files_set - img_files_set
in_img_not_csv = img_files_set - csv_files_set
matched        = csv_files_set & img_files_set

print('='*55)
print('  KONSISTENSI CSV ↔ FOLDER GAMBAR')
print('='*55)
print(f'  Matched (ada di keduanya)    : {len(matched)}')
print(f'  Ada di CSV, TIDAK di folder  : {len(in_csv_not_img)}')
print(f'  Ada di folder, TIDAK di CSV  : {len(in_img_not_csv)}')

match_rate = len(matched) / max(len(csv_files_set), len(img_files_set)) * 100
print(f'\n  ✅ Match rate: {match_rate:.1f}%')

if in_csv_not_img:
    print(f'\n  Contoh file di CSV tapi tidak ada gambar:')
    for f in list(in_csv_not_img)[:5]: print(f'    - {f}')

if in_img_not_csv:
    print(f'\n  Contoh gambar tidak ada di CSV:')
    for f in list(in_img_not_csv)[:5]: print(f'    - {f}')
# Out:
# =======================================================
#   KONSISTENSI CSV ↔ FOLDER GAMBAR
# =======================================================
#   Matched (ada di keduanya)    : 2490
#   Ada di CSV, TIDAK di folder  : 0
#   Ada di folder, TIDAK di CSV  : 0
#
#   ✅ Match rate: 100.0%

# %% [markdown]
# ## 5. Deteksi Anomali Gambar

# %%
# Threshold anomali — sesuaikan jika perlu
BLUR_THRESHOLD       = 50    # di bawah ini = blur/buram
BRIGHTNESS_LOW       = 30    # terlalu gelap
BRIGHTNESS_HIGH      = 225   # terlalu terang/overexposed
ASPECT_RATIO_MAX     = 15.0  # terlalu panjang/sempit
MIN_WIDTH            = 30    # terlalu kecil
MIN_HEIGHT           = 10

df_img['is_blur']      = df_img['blur_score'] < BLUR_THRESHOLD
df_img['is_dark']      = df_img['brightness'] < BRIGHTNESS_LOW
df_img['is_bright']    = df_img['brightness'] > BRIGHTNESS_HIGH
df_img['is_odd_ratio'] = df_img['aspect_ratio'] > ASPECT_RATIO_MAX
df_img['is_too_small'] = (df_img['width'] < MIN_WIDTH) | (df_img['height'] < MIN_HEIGHT)
df_img['any_issue']    = (
    df_img['is_blur'] | df_img['is_dark'] | df_img['is_bright'] |
    df_img['is_odd_ratio'] | df_img['is_too_small']
)

print('='*55)
print('  DETEKSI ANOMALI GAMBAR')
print('='*55)
print(f'  Gambar blur (blur_score < {BLUR_THRESHOLD})  : {df_img["is_blur"].sum()}')
print(f'  Gambar terlalu gelap (<{BRIGHTNESS_LOW} brightness) : {df_img["is_dark"].sum()}')
print(f'  Gambar overexposed (>{BRIGHTNESS_HIGH})        : {df_img["is_bright"].sum()}')
print(f'  Rasio aspek ekstrem (>{ASPECT_RATIO_MAX})       : {df_img["is_odd_ratio"].sum()}')
print(f'  Gambar terlalu kecil              : {df_img["is_too_small"].sum()}')
print(f'  ─────────────────────────────────')
print(f'  Total gambar bermasalah           : {df_img["any_issue"].sum()} ({df_img["any_issue"].mean()*100:.1f}%)')

# Simpan daftar anomali
anomaly_path = os.path.join(OUTPUT_DIR, 'anomaly_images.csv')
df_img[df_img['any_issue']].to_csv(anomaly_path, index=False)
print(f'\n  📄 Daftar gambar anomali disimpan: {anomaly_path}')
# Out:
# =======================================================
#   DETEKSI ANOMALI GAMBAR
# =======================================================
#   Gambar blur (blur_score < 50)  : 483
#   Gambar terlalu gelap (<30 brightness) : 3
#   Gambar overexposed (>225)        : 29
#   Rasio aspek ekstrem (>15.0)       : 132
#   Gambar terlalu kecil              : 0
#   ─────────────────────────────────
#   Total gambar bermasalah           : 602 (24.2%)
#
#   📄 Daftar gambar anomali disimpan: /content/drive/MyDrive/ocr_crop_v3/eda_output/anomaly_images.csv

# %% [markdown]
# ## 6. Dashboard Visualisasi

# %%
fig = plt.figure(figsize=(22, 18))
fig.suptitle(
    'EDA Dataset OCR — Informasi Gizi Kemasan Makanan',
    fontsize=18, fontweight='bold', y=0.98
)
gs = gridspec.GridSpec(3, 3, figure=fig, hspace=0.45, wspace=0.35)

PALETTE = 'viridis'

# ── Plot 1: Class Balance (gambar) ────────────────────────────
ax1 = fig.add_subplot(gs[0, 0])
class_count = df_img['class'].value_counts()
bars = sns.barplot(x=class_count.index, y=class_count.values, ax=ax1, palette=PALETTE)
ax1.set_title('Distribusi Kelas (Gambar)', fontweight='bold')
ax1.set_ylabel('Jumlah Gambar')
ax1.set_xlabel('Kelas Nutrisi')
ax1.bar_label(ax1.containers[0], fontsize=9)
ax1.tick_params(axis='x', rotation=15)

# ── Plot 2: Distribusi Panjang Teks ───────────────────────────
ax2 = fig.add_subplot(gs[0, 1])
sns.histplot(df_label['text_len'], bins=30, kde=True, ax=ax2, color='steelblue')
ax2.set_title('Distribusi Panjang Teks Label (CSV)', fontweight='bold')
ax2.set_xlabel('Panjang Teks (karakter)')
ax2.set_ylabel('Frekuensi')
ax2.axvline(df_label['text_len'].median(), color='red', linestyle='--', label=f'Median={df_label["text_len"].median():.0f}')
ax2.legend(fontsize=8)

# ── Plot 3: Resolusi Scatter ───────────────────────────────────
ax3 = fig.add_subplot(gs[0, 2])
classes_uniq = df_img['class'].unique()
palette_map  = dict(zip(classes_uniq, sns.color_palette(PALETTE, len(classes_uniq))))
for cls in classes_uniq:
    sub = df_img[df_img['class'] == cls]
    ax3.scatter(sub['width'], sub['height'], label=cls, alpha=0.5, s=10, color=palette_map[cls])
ax3.set_title('Sebaran Resolusi per Kelas', fontweight='bold')
ax3.set_xlabel('Lebar (px)')
ax3.set_ylabel('Tinggi (px)')
ax3.legend(fontsize=7, markerscale=2)

# ── Plot 4: Distribusi Rasio Aspek ────────────────────────────
ax4 = fig.add_subplot(gs[1, 0])
sns.histplot(df_img['aspect_ratio'].clip(upper=20), bins=40, kde=True, ax=ax4, color='coral')
ax4.set_title('Distribusi Rasio Aspek (W/H)', fontweight='bold')
ax4.set_xlabel('Rasio Aspek')
ax4.axvline(df_img['aspect_ratio'].median(), color='red', linestyle='--',
            label=f'Median={df_img["aspect_ratio"].median():.1f}')
ax4.legend(fontsize=8)

# ── Plot 5: Distribusi Blur Score ─────────────────────────────
ax5 = fig.add_subplot(gs[1, 1])
sns.histplot(df_img['blur_score'].clip(upper=500), bins=40, kde=True, ax=ax5, color='mediumseagreen')
ax5.set_title('Distribusi Blur Score (Laplacian Var)', fontweight='bold')
ax5.set_xlabel('Blur Score (lebih tinggi = lebih tajam)')
ax5.axvline(BLUR_THRESHOLD, color='red', linestyle='--', label=f'Threshold={BLUR_THRESHOLD}')
ax5.legend(fontsize=8)

# ── Plot 6: Distribusi Brightness ─────────────────────────────
ax6 = fig.add_subplot(gs[1, 2])
sns.histplot(df_img['brightness'], bins=40, kde=True, ax=ax6, color='goldenrod')
ax6.set_title('Distribusi Brightness (Mean Grayscale)', fontweight='bold')
ax6.set_xlabel('Brightness (0=gelap, 255=terang)')
ax6.axvline(BRIGHTNESS_LOW,  color='blue',   linestyle='--', label=f'Min={BRIGHTNESS_LOW}')
ax6.axvline(BRIGHTNESS_HIGH, color='red',    linestyle='--', label=f'Max={BRIGHTNESS_HIGH}')
ax6.legend(fontsize=8)

# ── Plot 7: Anomali per Kelas ─────────────────────────────────
ax7 = fig.add_subplot(gs[2, 0])
anomaly_by_class = df_img.groupby('class')['any_issue'].sum().sort_values(ascending=False)
sns.barplot(x=anomaly_by_class.index, y=anomaly_by_class.values, ax=ax7, palette='Reds_r')
ax7.set_title('Jumlah Gambar Bermasalah per Kelas', fontweight='bold')
ax7.set_ylabel('Jumlah Anomali')
ax7.set_xlabel('Kelas')
ax7.bar_label(ax7.containers[0], fontsize=9)
ax7.tick_params(axis='x', rotation=15)

# ── Plot 8: Boxplot Dimensi per Kelas ────────────────────────
ax8 = fig.add_subplot(gs[2, 1])
sns.boxplot(data=df_img, x='class', y='width', ax=ax8, palette=PALETTE)
ax8.set_title('Distribusi Lebar (px) per Kelas', fontweight='bold')
ax8.set_xlabel('Kelas')
ax8.set_ylabel('Lebar (px)')
ax8.tick_params(axis='x', rotation=15)

# ── Plot 9: Ringkasan Numerik ─────────────────────────────────
ax9 = fig.add_subplot(gs[2, 2])
ax9.axis('off')
summary_text = (
    f"RINGKASAN DATASET\n"
    f"{'─'*32}\n"
    f"Total gambar          : {len(df_img)}\n"
    f"Total label CSV       : {len(df_label)}\n"
    f"Match rate            : {match_rate:.1f}%\n"
    f"\nGAMBAR\n"
    f"{'─'*32}\n"
    f"Resolusi rata-rata    : {df_img['width'].mean():.0f}x{df_img['height'].mean():.0f} px\n"
    f"Rasio aspek median    : {df_img['aspect_ratio'].median():.2f}\n"
    f"Blur (median score)   : {df_img['blur_score'].median():.1f}\n"
    f"Total anomali         : {df_img['any_issue'].sum()} ({df_img['any_issue'].mean()*100:.1f}%)\n"
    f"\nCSV LABEL\n"
    f"{'─'*32}\n"
    f"Missing/kosong        : {missing + empty}\n"
    f"Duplikat file_name    : {dup_rows}\n"
    f"Panjang teks median   : {df_label['text_len'].median():.0f} karakter\n"
    f"Kelas unik            : {df_label['class'].nunique()}\n"
)
ax9.text(0.05, 0.95, summary_text, transform=ax9.transAxes,
         fontsize=9.5, verticalalignment='top', fontfamily='monospace',
         bbox=dict(boxstyle='round', facecolor='#f0f4f8', alpha=0.8))

# ── Simpan ────────────────────────────────────────────────────
out_path = os.path.join(OUTPUT_DIR, 'eda_dashboard.png')
plt.savefig(out_path, dpi=200, bbox_inches='tight')
plt.show()
print(f'\n✅ Dashboard disimpan: {out_path}')
# Out:
# ✅ Dashboard disimpan: /content/drive/MyDrive/ocr_crop_v3/eda_output/eda_dashboard.png

# %% [markdown]
# ## 7. Export Laporan CSV Lengkap

# %%
# Gabungkan df_img + df_label jadi satu tabel lengkap
df_full = df_img.merge(df_label[['file_name', 'text', 'text_len']], on='file_name', how='left')

# Simpan laporan lengkap
full_path = os.path.join(OUTPUT_DIR, 'eda_full_report.csv')
df_full.to_csv(full_path, index=False, encoding='utf-8-sig')
print(f'✅ Laporan lengkap disimpan: {full_path}')
print(f'   Shape: {df_full.shape}')
df_full.head()
# Out:
# ✅ Laporan lengkap disimpan: /content/drive/MyDrive/ocr_crop_v3/eda_output/eda_full_report.csv
#    Shape: (2490, 16)
#          file_name   class  width  height  aspect_ratio  megapixels  \
# 0   sugar_0560.png   sugar    537      90         5.967      0.0483
# 1   sugar_0580.png   sugar    871      89         9.787      0.0775
# 2   carbs_0202.png   carbs    964     138         6.986      0.1330
# 3   sugar_0588.png   sugar   1105      97        11.392      0.1072
# 4  sodium_0137.png  sodium    321      67         4.791      0.0215
#
#    blur_score  brightness  is_blur  is_dark  is_bright  is_odd_ratio  \
# 0      163.80      163.14    False    False      False         False
# 1      191.71      154.21    False    False      False         False
# 2      441.24      165.95    False    False      False         False
# 3      363.41       59.29    False    False      False         False
# 4      385.08      196.82    False    False      False         False
#
#    is_too_small  any_issue                                         text  \
# 0         False      False                                     Gula 1 g
# 1         False      False                           Gula / Sugars 40 g
# 2         False      False  Karbohidrat Total / Total Carbohydrate 12 g
# 3         False      False                            Gula / Sugar 10 g
# 4         False      False                                Sodium 105 mg
#
#    text_len
# 0         8
# 1        18
# 2        43
# 3        17
# 4        13

# %% [markdown]
# ## 8. Rekomendasi untuk AI Engineer

# %%
print('='*60)
print('  REKOMENDASI UNTUK AI ENGINEER (CRNN TRAINING)')
print('='*60)

blur_pct    = df_img['is_blur'].mean() * 100
anomaly_pct = df_img['any_issue'].mean() * 100
class_counts = df_img['class'].value_counts()
imbalance_ratio = class_counts.max() / class_counts.min() if class_counts.min() > 0 else float('inf')

recs = []

# 1. Kualitas gambar
if blur_pct > 10:
    recs.append(f'⚠️  [{blur_pct:.1f}% gambar blur] Pertimbangkan augmentasi sharpening atau filter gambar blur sebelum training.')
else:
    recs.append(f'✅  Kualitas ketajaman gambar baik ({blur_pct:.1f}% blur).')

# 2. Class balance
if imbalance_ratio > 2:
    recs.append(f'⚠️  [Imbalance ratio={imbalance_ratio:.1f}x] Dataset tidak seimbang. Gunakan class_weight atau oversampling (augmentasi) pada kelas minoritas.')
else:
    recs.append(f'✅  Class balance cukup baik (ratio={imbalance_ratio:.1f}x).')

# 3. Resolusi
median_h = df_img['height'].median()
if median_h < 32:
    recs.append(f'⚠️  [Median tinggi={median_h:.0f}px] Terlalu kecil untuk CRNN. Rekomendasikan resize ke tinggi 32–64px.')
else:
    recs.append(f'✅  Tinggi gambar cukup untuk CRNN (median={median_h:.0f}px). Target resize: 32px atau 64px.')

# 4. CSV
if missing + empty > 0:
    recs.append(f'⚠️  [{missing+empty} label kosong] Hapus atau perbaiki sebelum training untuk menghindari error loss.')
else:
    recs.append('✅  Tidak ada label kosong dalam CSV.')

# 5. Match rate
if match_rate < 98:
    recs.append(f'⚠️  [Match rate={match_rate:.1f}%] Ada ketidakcocokan antara gambar dan CSV. Selaraskan sebelum training.')
else:
    recs.append(f'✅  Konsistensi CSV-gambar sangat baik ({match_rate:.1f}%).')

# 6. Preprocessing saran
recs.append('📌 Saran preprocessing CRNN:')
recs.append('   - Resize semua gambar ke tinggi tetap (32px atau 64px), lebar proporsional')
recs.append('   - Normalisasi pixel ke [0,1] atau [-1,1]')
recs.append('   - Gunakan CTC Loss untuk training sequence labeling')
recs.append('   - Split dataset: 80% train / 10% val / 10% test (stratified per kelas)')

print()
for r in recs:
    print(f'  {r}')

# Simpan rekomendasi ke txt
rec_path = os.path.join(OUTPUT_DIR, 'rekomendasi_ai_engineer.txt')
with open(rec_path, 'w', encoding='utf-8') as f:
    f.write('REKOMENDASI UNTUK AI ENGINEER — CRNN TRAINING\n')
    f.write('='*60 + '\n')
    for r in recs:
        f.write(r + '\n')
print(f'\n📄 Rekomendasi disimpan: {rec_path}')
# Out:
# ============================================================
#   REKOMENDASI UNTUK AI ENGINEER (CRNN TRAINING)
# ============================================================
#
#   ⚠️  [19.4% gambar blur] Pertimbangkan augmentasi sharpening atau filter gambar blur sebelum training.
#   ✅  Class balance cukup baik (ratio=1.0x).
#   ✅  Tinggi gambar cukup untuk CRNN (median=96px). Target resize: 32px atau 64px.
#   ✅  Tidak ada label kosong dalam CSV.
#   ✅  Konsistensi CSV-gambar sangat baik (100.0%).
#   📌 Saran preprocessing CRNN:
#      - Resize semua gambar ke tinggi tetap (32px atau 64px), lebar proporsional
#      - Normalisasi pixel ke [0,1] atau [-1,1]
#      - Gunakan CTC Loss untuk training sequence labeling
#      - Split dataset: 80% train / 10% val / 10% test (stratified per kelas)
#
# 📄 Rekomendasi disimpan: /content/drive/MyDrive/ocr_crop_v3/eda_output/rekomendasi_ai_engineer.txt

# %% [markdown]
# ---
# ## Catatan Akhir
#
# File output tersimpan di `D:/ocr_crop_V3/eda_output/`:
# | File | Isi |
# |---|---|
# | `eda_dashboard.png` | Dashboard visualisasi lengkap (untuk laporan) |
# | `eda_full_report.csv` | Tabel gabungan semua fitur gambar + label |
# | `anomaly_images.csv` | Daftar gambar yang terdeteksi bermasalah |
# | `rekomendasi_ai_engineer.txt` | Ringkasan rekomendasi tertulis |
